# %% [markdown]
# # 2019-04-07
#
# ``` txt
# file:///Users/zijin/projects/autoplot/psp_mag_sw.vap?timerange=2019-04-06+through+2019-04-08
# file:///Users/zijin/projects/autoplot/ace.vap?timerange=2019-04-08+through+2019-04-10
# file:///Users/zijin/projects/autoplot/ace.vap?timerange=2019-04-11+through+2019-04-14
# file:///Users/zijin/projects/autoplot/wind_plasma.vap?timerange=2019-04-08+through+2019-04-10
# file:///Users/zijin/projects/autoplot/dscovr.vap?timerange=2019-04-08+through+2019-04-10
# ```
#
# [ENLIL Solar Wind Prediction - Parker Solar Probe - Perihelion 02](http://helioweather.net/missions/psp/per02/)
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <tbody>
# <tr class="odd">
# <td style="text-align: left;"><div width="50.0%" data-layout-align="left">
# <p><a href="http://helioweather.net/missions/psp/per02/anim/tuz-a7b1-d4t05x1-d200t1-donki_den1-psp-x15wifs3z1fo_med_201903-201904.mp4">http://helioweather.net/missions/psp/per02/anim/tuz-a7b1-d4t05x1-d200t1-donki_den1-psp-x15wifs3z1fo_med_201903-201904.mp4</a></p>
# </div></td>
# <td style="text-align: left;"><div width="50.0%" data-layout-align="left">
# <p><a href="http://helioweather.net/missions/psp/per02/anim/tuz-a7b1-d4t05x1-d200t1-donki_vel2e1-psp-x15ifs3z1fr_med_201903-201904.mp4">http://helioweather.net/missions/psp/per02/anim/tuz-a7b1-d4t05x1-d200t1-donki_vel2e1-psp-x15ifs3z1fr_med_201903-201904.mp4</a></p>
# </div></td>
# </tr>
# </tbody>
# </table>
#
# ![](attachment:../images/paste-15.png)
#
# <table style="width:100%;">
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <tbody>
# <tr class="odd">
# <td style="text-align: left;"><div width="33.3%" data-layout-align="left">
# <figure>
# <img src="attachment:../images/paste-18.png" alt="PSP observation" />
# <figcaption aria-hidden="true">PSP observation</figcaption>
# </figure>
# </div></td>
# <td style="text-align: left;"><div width="33.3%" data-layout-align="left">
# <figure>
# <img src="attachment:../images/paste-16.png" alt="ACE observation" />
# <figcaption aria-hidden="true">ACE observation</figcaption>
# </figure>
# </div></td>
# <td style="text-align: left;"><div width="33.3%" data-layout-align="left">
# <figure>
# <img src="attachment:../images/paste-17.png" alt="ACE observation (continued)" />
# <figcaption aria-hidden="true">ACE observation (continued)</figcaption>
# </figure>
# </div></td>
# </tr>
# </tbody>
# </table>
#
# Summary plot
#
# <table>
# <colgroup>
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# </colgroup>
# <tbody>
# <tr class="odd">
# <td style="text-align: center;"><div width="25.0%" data-layout-align="center">
# <p><img src="https://psp-gateway.jhuapl.edu/backend/data/summary_plots/Summary_Plot_20190405.png" /></p>
# </div></td>
# <td style="text-align: center;"><div width="25.0%" data-layout-align="center">
# <p><img src="https://psp-gateway.jhuapl.edu/backend/data/summary_plots/Summary_Plot_20190406.png" /></p>
# </div></td>
# <td style="text-align: center;"><div width="25.0%" data-layout-align="center">
# <p><img src="https://psp-gateway.jhuapl.edu/backend/data/summary_plots/Summary_Plot_20190407.png" /></p>
# </div></td>
# <td style="text-align: center;"><div width="25.0%" data-layout-align="center">
# <p><img src="https://psp-gateway.jhuapl.edu/backend/data/summary_plots/Summary_Plot_20190408.png" /></p>
# </div></td>
# </tr>
# </tbody>
# </table>
